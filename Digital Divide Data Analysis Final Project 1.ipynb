# %% [markdown]
# # Digital Divide Exploratory Data Analysis Project

# %% [markdown]
# By: Elston Bell, Jr.

# %% [markdown]
# ## Report Layout:

# %% [markdown]
# - Introduction
# - Data Cleaning
# - Data Analysis
# - Summary
# - Recommendations
# - Conclusion

# %% [markdown]
# # Introduction

# %% [markdown]
# ### What is the digital divide?

# %% [markdown]
# The uneven distribution of information and communication technologies in society.
#
# As the world of technology is rapidly increasing, so is the gap for individuals who lack access to these same worldchanging technologies. This issue becomes increasingly important when we begin to look critically at the individuals and commuities this technological inequity affects most.  ![external-content.duckduckgo.jpg](attachment:external-content.duckduckgo.jpg)

# %% [markdown]
# ### Purpose:

# %% [markdown]
# Innovation and entrepreneurship have become the bedrock of shaping the future, and with visionaries focusing on the creation of social impact organizations, such as TKH, who are working diligently to low barriers and create opportunities in the technology industy.
#
# This data can provide insight into areas that are most in need, the resources they may need most and ultimately where the program can potentially have the greatest impact. This report will show areas and considerable factors to think of when deciding strategies for making the most impact. Hopefully this report will aid in:
# - a greater understanding of the digital divide and why it matters
# - who it impacts
# - what locations need the most support
# - what we can collectively do about it
# ![external-content.duckduckgo-2.jpg](attachment:external-content.duckduckgo-2.jpg)

# %% [markdown]
# ## Hypothesis:

# %% [markdown]
# With the poverty rate as our main indicator, the higher the poverty rate the more affected the area of interest will by affected by the digital divide. Higher poverty rate will coincide with high rates of no internet and no computers.

# %% [markdown]
# ### About the Dataset

# %% [markdown]
# US Broadband Availability
#
# Counties in the U.S. refer to region within states having distinct boundaries and a form of official authority. Some states such as Alaska and Texas have county equivalents. There are 3,007 counties and 135 county equivalents resulting in 3,142 total counties, which we see reflected in out total number of counties. (1)
# Also, this dataset was sourced from the Institute of Museum and Library Services,

# %%
#Importing of pandas library
import pandas as pd

#Reading of csv file into notebook and creation of dataframe 
data = pd.read_csv('broadband_access.csv')
df = pd.DataFrame(data)
df
# Out:
#                        full_name      county    state state_abr  population  \
# 0        Autauga County, Alabama     Autauga  Alabama        AL     55869.0
# 1        Baldwin County, Alabama     Baldwin  Alabama        AL    223234.0
# 2        Barbour County, Alabama     Barbour  Alabama        AL     24686.0
# 3           Bibb County, Alabama        Bibb  Alabama        AL     22394.0
# 4         Blount County, Alabama      Blount  Alabama        AL     57826.0
# ...                          ...         ...      ...       ...         ...
# 3137  Sweetwater County, Wyoming  Sweetwater  Wyoming        WY     42343.0
# 3138       Teton County, Wyoming       Teton  Wyoming        WY     23464.0
# 3139       Uinta County, Wyoming       Uinta  Wyoming        WY     20226.0
# 3140    Washakie County, Wyoming    Washakie  Wyoming        WY      7805.0
# 3141      Weston County, Wyoming      Weston  Wyoming        WY      6927.0
#
# ...

# %%
df.shape
# Out:
# (3142, 23)

# %%
df.head()
# Out:
#                  full_name   county    state state_abr  population  unemp  \
# 0  Autauga County, Alabama  Autauga  Alabama        AL     55869.0    2.7
# 1  Baldwin County, Alabama  Baldwin  Alabama        AL    223234.0    2.7
# 2  Barbour County, Alabama  Barbour  Alabama        AL     24686.0    3.8
# 3     Bibb County, Alabama     Bibb  Alabama        AL     22394.0    3.1
# 4   Blount County, Alabama   Blount  Alabama        AL     57826.0    2.7
#
#    health_ins  poverty  SNAP  no_comp  ...  broad_avail  broad_cost  \
# 0         7.1     15.4  12.7     13.0  ...          0.0         NaN
# 1        10.2     10.6   7.5     11.4  ...          0.0         NaN
# 2        11.2     28.9  27.4     23.9  ...         99.2       74.99
# 3         7.9     14.0  12.4     23.7  ...          0.0         NaN
# 4        11.0     14.4   9.5     21.3  ...          0.0         NaN
#
#    population_bbn  price_bbn  wired_bbn  provide_bbn  all25_bbn  downave_bbn  \
# ...

# %%
#Looking for null values  
df.isnull().sum()

#There are some missing values
#Null values are taken care of in mean function
# Out:
# full_name           0
# county              0
# state               0
# state_abr           0
# population          0
# unemp               1
# health_ins          0
# poverty             1
# SNAP                0
# no_comp             0
# no_internet         0
# home_broad          0
# broad_num           1
# broad_avail         1
# broad_cost         40
# population_bbn     14
# price_bbn         111
# wired_bbn          14
# provide_bbn        14
# all25_bbn          14
# downave_bbn        14
# access_bbn         14
# slowfrac_bbn       14
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3142 entries, 0 to 3141
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   full_name       3142 non-null   object
#  1   county          3142 non-null   object
#  2   state           3142 non-null   object
#  3   state_abr       3142 non-null   object
#  4   population      3142 non-null   float64
#  5   unemp           3141 non-null   float64
#  6   health_ins      3142 non-null   float64
#  7   poverty         3141 non-null   float64
#  8   SNAP            3142 non-null   float64
#  9   no_comp         3142 non-null   float64
#  10  no_internet     3142 non-null   float64
#  11  home_broad      3142 non-null   float64
#  12  broad_num       3141 non-null   float64
#  13  broad_avail     3141 non-null   float64
#  14  broad_cost      3102 non-null   float64
#  15  population_bbn  3128 non-null   float64
#  16  price_bbn       3031 non-null   float64
# ...

# %%
df.describe()
# Out:
#          population        unemp   health_ins      poverty         SNAP  \
# count  3.142000e+03  3141.000000  3142.000000  3141.000000  3142.000000
# mean   1.044683e+05     4.001178    10.081954    15.601210    13.224889
# std    3.334567e+05     1.484455     5.099991     6.478484     6.518802
# min    8.600000e+01     0.700000     1.700000     2.300000     0.000000
# 25%    1.090250e+04     3.000000     6.200000    11.000000     8.600000
# 50%    2.572600e+04     3.700000     9.200000    14.700000    12.400000
# 75%    6.807275e+04     4.600000    12.675000    19.100000    16.800000
# max    1.003911e+07    19.300000    45.600000    55.100000    59.900000
#
#            no_comp  no_internet   home_broad    broad_num  broad_avail  \
# count  3142.000000  3142.000000  3142.000000  3141.000000  3141.000000
# mean     16.584341    26.577276    72.690866     4.134352    73.839924
# std       6.935272     9.168434     9.255863     2.284628    24.737063
# ...

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## State Overview

# %% [markdown]
# To start, I decided to group the data by the state, so we can take a look at some trends. The shape of this dataframe consists of 51 rows and that's because it contains DC as a state. Also, when aggregating as the mean function is doing, it accounts for null values and does not include them in the calculation, which is why I haven't had to drop the null values in cleaning.

# %%
overview = df.groupby(['state'],as_index = False).mean()
overview
# Out:
#                    state     population     unemp  health_ins    poverty  \
# 0                Alabama   73181.865672  3.446269   10.488060  20.337313
# 1                 Alaska   25225.689655  8.320690   19.934483  13.317241
# 2                Arizona  485247.800000  6.446667   11.640000  20.000000
# 3               Arkansas   40237.386667  4.184000    8.637333  19.833333
# 4             California  681245.224138  5.098276    7.808621  15.020690
# 5               Colorado   89980.250000  2.843750    9.751563  13.062500
# 6            Connecticut  445660.875000  3.625000    4.637500   9.162500
# 7               Delaware  324588.000000  3.900000    6.466667  12.233333
# 8   District of Columbia  705749.000000  5.500000    4.000000  16.800000
# 9                Florida  320563.238806  3.477612   13.434328  16.589552
# 10               Georgia   66776.245283  3.904403   14.709434  20.664780
# 11                Hawaii  283174.400000  2.825000    4.340000  10.820000
# ...

# %%
overview.shape

#considers DC a state
# Out:
# (51, 20)

# %%
dd1 = overview[['state','poverty','no_comp','no_internet']]
dd1
# Out:
#                    state    poverty    no_comp  no_internet
# 0                Alabama  20.337313  22.944776    33.577612
# 1                 Alaska  13.317241  11.262069    23.951724
# 2                Arizona  20.000000  16.613333    27.780000
# 3               Arkansas  19.833333  20.741333    35.129333
# 4             California  15.020690  10.837931    18.086207
# 5               Colorado  13.062500  11.737500    20.389063
# 6            Connecticut   9.162500  10.112500    15.450000
# 7               Delaware  12.233333  10.500000    17.666667
# 8   District of Columbia  16.800000  10.200000    19.700000
# 9                Florida  16.589552  14.880597    24.301493
# 10               Georgia  20.664780  20.080503    31.700629
# 11                Hawaii  10.820000  13.540000    22.540000
# 12                 Idaho  14.981818  12.559091    22.822727
# 13              Illinois  13.589216  16.277451    24.061765
# 14               Indiana  12.941304  14.818478    25.058696
# ...

# %%
import seaborn as sns

#plt.scatter(overview["poverty"], overview["no_internet"])
sns.set_style("white")
gridobj = sns.lmplot(x="poverty", y="no_internet", data= overview, 
                     height=5, aspect=1.3, robust=True, palette='tab10', 
                     scatter_kws=dict(s=60, linewidths=.7, edgecolors='black'))

# %%
#plt.scatter(overview["poverty"], overview["no_comp"])

sns.set_style("white")
gridobj = sns.lmplot(x="poverty", y="no_comp", data= overview, 
                     height=5, aspect=1.3, robust=True, palette='tab10', 
                     scatter_kws=dict(s=60, linewidths=.7, edgecolors='black'))

# %% [markdown]
# ## Top 25% of states with the lowest poverty rate

# %%
lowest_poverty = dd1.sort_values(by=['poverty'],ascending=True, kind='quicksort')[['state','poverty']].head(13)
lowest_poverty
# Out:
#             state    poverty
# 6     Connecticut   9.162500
# 29  New Hampshire   9.170000
# 39   Rhode Island   9.960000
# 30     New Jersey  10.176190
# 20       Maryland  10.358333
# 34   North Dakota  10.611321
# 21  Massachusetts  10.692857
# 23      Minnesota  10.752874
# 11         Hawaii  10.820000
# 27       Nebraska  11.002151
# 15           Iowa  11.096970
# 45        Vermont  11.271429
# 49      Wisconsin  11.518056

# %%
#Try to make a lollipop chart with the rate above the circle 

#fig, axes = plt.subplots()
#axes.vlines(lowest_poverty, ymin=0, ymax=lowest_poverty)
#axes.plot(lowest_poverty, lowest_poverty, "o")
#axes.set_ylim(0)

import pandas as pd
import matplotlib.pyplot as plt

my_range=range(0,len(lowest_poverty))

plt.figure(figsize =(10,6),tight_layout=True)
plt.margins(.1)
plt.stem(lowest_poverty['poverty'])
plt.xticks(my_range,lowest_poverty['state'],rotation = 90)

for idx, row in enumerate(lowest_poverty.itertuples()):
    plt.text(idx, row.poverty+.2, s=f'{row.poverty/100:.2%}', horizontalalignment= 'center', verticalalignment='bottom', fontsize=10)

plt.show()

# %% [markdown]
# ## Top 25% of states with the highest poverty rate

# %%
highest_poverty = dd1.sort_values(by=['poverty'],ascending=False, kind='quicksort')[['state','poverty']].head(13)
highest_poverty
# Out:
#              state    poverty
# 24     Mississippi  24.148780
# 18       Louisiana  21.995312
# 31      New Mexico  21.115625
# 17        Kentucky  20.985000
# 10         Georgia  20.664780
# 0          Alabama  20.337313
# 2          Arizona  20.000000
# 3         Arkansas  19.833333
# 40  South Carolina  19.445652
# 48   West Virginia  18.429091
# 42       Tennessee  17.889474
# 33  North Carolina  17.518000
# 36        Oklahoma  17.032468

# %%
import pandas as pd
import matplotlib.pyplot as plt

my_range=range(0,len(lowest_poverty))

plt.figure(figsize =(10,6),tight_layout=True)
plt.margins(.1)
plt.stem(highest_poverty['poverty'])
plt.xticks(my_range,highest_poverty['state'],rotation = 90)

for idx, row in enumerate(highest_poverty.itertuples()):
    plt.text(idx, row.poverty+.2, s=f'{row.poverty/100:.2%}', horizontalalignment= 'center', verticalalignment='bottom', fontsize=10)

plt.show()

# %% [markdown]
# ## Correlogram

# %% [markdown]
# A graph to show the correlation between variables.

# %%
corr = overview[['state','poverty','no_comp','no_internet']].corr()
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid')
# %matplotlib inline
plt.figure(figsize=(12,8))
plt.title('Correlation Between Poverty Rate and Lack of Access to Internet & Computers by State')
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:title={'center':'Correlation Between Poverty Rate and Lack of Access to Internet & Computers by State'}>

# %%
#Rank the poverty level 

no_internet = overview.sort_values(by=['no_internet'],ascending=False, kind='quicksort')[['state','poverty','no_internet']]
no_internet

#Creating a column called rank which will rank the states in descending order with respect to poverty level 
no_internet["Rank"] = no_internet["poverty"].rank(ascending=False)


no_internet

#https://www.dataindependent.com/pandas/pandas-rank/
# Out:
#                    state    poverty  no_internet  Rank
# 24           Mississippi  24.148780    38.337805   1.0
# 31            New Mexico  21.115625    35.524242   3.0
# 3               Arkansas  19.833333    35.129333   8.0
# 0                Alabama  20.337313    33.577612   6.0
# 18             Louisiana  21.995312    33.559375   2.0
# 40        South Carolina  19.445652    31.939130   9.0
# 10               Georgia  20.664780    31.700629   5.0
# 42             Tennessee  17.889474    30.641053  11.0
# 36              Oklahoma  17.032468    30.602597  13.0
# 17              Kentucky  20.985000    30.172500   4.0
# 48         West Virginia  18.429091    29.360000  10.0
# 43                 Texas  16.056299    29.231496  17.0
# 25              Missouri  16.633913    28.582609  15.0
# 2                Arizona  20.000000    27.780000   7.0
# 33        North Carolina  17.518000    27.769000  12.0
# 41          South Dakota  15.884848    27.696970  18.0
# ...

# %%
no_internet = dd1.sort_values(by=['no_internet'],ascending=False, kind='quicksort')[['state','poverty','no_internet']].head(13)
no_internet
# Out:
#              state    poverty  no_internet
# 24     Mississippi  24.148780    38.337805
# 31      New Mexico  21.115625    35.524242
# 3         Arkansas  19.833333    35.129333
# 0          Alabama  20.337313    33.577612
# 18       Louisiana  21.995312    33.559375
# 40  South Carolina  19.445652    31.939130
# 10         Georgia  20.664780    31.700629
# 42       Tennessee  17.889474    30.641053
# 36        Oklahoma  17.032468    30.602597
# 17        Kentucky  20.985000    30.172500
# 48   West Virginia  18.429091    29.360000
# 43           Texas  16.056299    29.231496
# 25        Missouri  16.633913    28.582609

# %% [markdown]
# ## Combination Chart

# %%
#Make a combination chart

fig = plt.figure(figsize =(16,5))
ax1 = plt.subplot(1,1,1)
ax1.bar(no_internet.state, no_internet.no_internet)
plt.xlabel('State')
plt.ylabel('%No Internet')

#ax1.set_xlim(0,no_internet.no_internet.max()*1.25)

ax2= ax1.twinx()
ax2.plot(no_internet.state, no_internet.poverty,'o-',color='red', linewidth = 2)
plt.ylabel('%Poverty Rate')
plt.title('No Internet & Poverty Rate by State')


plt.show()


#Resource 

#https://www.youtube.com/watch?v=PTy7hw7goeA

#Need to convert to percentages!!

# %% [markdown]
# # County Overview

# %% [markdown]
# ### Correlogram

# %%
corr = df[['full_name','poverty','no_comp','no_internet']].corr()
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid')
# %matplotlib inline
plt.figure(figsize=(12,8))
plt.title('Correlation Between Social Factors and Lack of Access to Internet & Computers')
sns.heatmap(corr, annot=True)

# %%
import seaborn as sns

#plt.scatter(overview["poverty"], overview["no_internet"])
sns.set_style("white")
gridobj = sns.lmplot(x="poverty", y="no_internet", data= df, 
                     height=5, aspect=1.3, robust=True, palette='tab10', 
                     scatter_kws=dict(s=60, linewidths=.7, edgecolors='black'))

# %%
df1= df.sort_values(by=['no_internet'],ascending=False, kind='quicksort')[['full_name','no_internet','poverty']].head(20)
df1

df1["Rank"] = df1["poverty"].rank(ascending=False)

df1
# Out:
#                                 full_name  no_internet  poverty  Rank
# 520               Telfair County, Georgia         74.1     28.2  10.0
# 1130       East Carroll Parish, Louisiana         66.7     48.6   2.0
# 539               Wheeler County, Georgia         66.6     26.8  13.5
# 1426           Holmes County, Mississippi         61.4     43.6   4.0
# 96                 Apache County, Arizona         61.0     35.3   8.0
# 1805         Guadalupe County, New Mexico         60.5     14.5  19.0
# 2408        Mellette County, South Dakota         59.7     48.3   3.0
# 1442          Leflore County, Mississippi         58.7     39.2   6.0
# 1166             Tensas Parish, Louisiana         57.2     40.0   5.0
# 517            Taliaferro County, Georgia         57.2     28.0  11.0
# 49                 Monroe County, Alabama         57.0     30.9   9.0
# 1433  Jefferson Davis County, Mississippi         56.8     27.0  12.0
# ...

# %%
import seaborn as sns

#plt.scatter(overview["poverty"], overview["no_internet"])
sns.set_style("white")
gridobj = sns.lmplot(x="poverty", y="no_comp", data= data, 
                     height=5, aspect=1.3, robust=True, palette='tab10', 
                     scatter_kws=dict(s=60, linewidths=.7, edgecolors='black'))

# %% [markdown]
# ## Combination Chart

# %%
#Make a combination chart

fig = plt.figure(figsize =(16,5))
ax1 = plt.subplot(1,1,1)
ax1.bar(df1.full_name, df1.no_internet)
plt.xlabel('State')
plt.ylabel('%No Internet')

#ax1.set_xlim(0,no_internet.no_internet.max()*1.25)

ax2= ax1.twinx()
ax2.plot(df1.full_name, df1.poverty,'o-',color='red', linewidth = 2)
plt.ylabel('%Poverty Rate')
plt.title('No Internet & Poverty Rate by County')


plt.show()


#Resource 

#https://www.youtube.com/watch?v=PTy7hw7goeA

# %% [markdown]
# ## Summary

# %% [markdown]
# On the state and county level:
# - There's a correlation between poverty rate, and the rate of those with no internet and no computer.
# - An even stronger correlation between no internet and no computer
# - An idea of the top 25% of states with respect to poverty rate
# - An idea of the 20 counties with the highest rate of no computer
#
# Based on our graph, our top 5 states of interest would be:
#    - Mississippi
#    - Louisiana
#    - New Mexico
#    - Kentucky
#    - Georgia
#
# Based on our graph, our top 5 counties of interest would be:
#    - East Carroll Parish, Louisiana
#    - Holmes County, Mississippi
#    - Mellette County, South Dakota
#    - Leflore County, Mississippi
#    - Tensas Parish, Louisiana

# %% [markdown]
# # Recommendations

# %% [markdown]
# The need is great
#
# 1) Create a partnership with an Internet provider, e.g. TKH gives out Mi-Fis, this could be an area of interest for programs looking to do the same. Provide internet access and computer access, personally I use both and it has been extremely impactful in being able to continue my coding career.
#
# Use this research for funding and partnerships
#
# 2) You can choose the state and decide on an area from there
# -teaming up with programs already doing the work & mentoring, sharing resources
# -places to run a smaller version of TKH
#
# Interesting that Mississippi, Louisiana and New Mexico are there because as Texas is becoming a hot spot and a lot of tech places are moving there it opens up opportunity for TKH to get in early and be a part of this tech revolution in the South, prime real estate and make an impact in a surroudning area as tech impacts the South.
#
#
# 3) Counties
# -incentives for virtual pop-up workshops
# -schools are a great place to start, community colleges, workforce programs that work with entry into coding

# %% [markdown]
# # Conclusion

# %%
With bold missions like

# %% [markdown]
# # Works Cited

# %%
https://www.worldatlas.com/articles/how-many-counties-are-in-the-united-states.html
https://worldpopulationreview.com/states/states-by-race
https://worldpopulationreview.com/state-rankings/educational-attainment-by-state 
https://worldpopulationreview.com/state-rankings/male-to-female-ratio-by-state
https://www.imls.gov/sites/default/files/users_guide_imls_nofo_metrics.pdf
https://www.census.gov/content/dam/Census/library/publications/2021/acs/acs-49.pdf
https://www.ncbroadband.gov/digital-divide#digital-literacy
https://www.imls.gov/data/data-catalog/imls-indicators-workbook-economic-status-and-broadband-availability-and-adoption
    
https://www.dataindependent.com/pandas/pandas-rank/
https://towardsdatascience.com/data-visualization-exploration-using-pandas-only-beginner-a0a52eb723d5
https://www.shanelynn.ie/pandas-iloc-loc-select-rows-and-columns-dataframe/
    
https://chartio.com/resources/tutorials/how-to-check-if-any-value-is-nan-in-a-pandas-dataframe/

# %%
1. Group by state
2. Determine KPI(s) 
3. Establish that I'll be looking at the top 25% and the bottom 25%, so the 13 countries at the extreme of a spectrum
3. Rank and show the similarity of some of these groups
- which visualization works best?
4.
5. Conclude with region and top 3 cities, along with suggestion for partnerships and resources they may need from the data

# %%
null_data = df[df.isnull().any(axis=1)]
null_data

# %%
df.loc[df['unemp'].isnull()]

# %%
a = pd.isnull(df["unemp"]=='True')
a

# %%
-Picture of equity
-Skills & Resources 
-Partnerships & stuff

# %% [raw]
# Works Cited

# %%
https://www.worldatlas.com/articles/how-many-counties-are-in-the-united-states.html
https://worldpopulationreview.com/states/states-by-race
https://worldpopulationreview.com/state-rankings/educational-attainment-by-state 
https://worldpopulationreview.com/state-rankings/male-to-female-ratio-by-state
https://www.imls.gov/sites/default/files/users_guide_imls_nofo_metrics.pdf
https://www.census.gov/content/dam/Census/library/publications/2021/acs/acs-49.pdf
https://www.ncbroadband.gov/digital-divide#digital-literacy
https://www.imls.gov/data/data-catalog/imls-indicators-workbook-economic-status-and-broadband-availability-and-adoption
    
https://www.dataindependent.com/pandas/pandas-rank/
https://towardsdatascience.com/data-visualization-exploration-using-pandas-only-beginner-a0a52eb723d5
https://www.shanelynn.ie/pandas-iloc-loc-select-rows-and-columns-dataframe/
